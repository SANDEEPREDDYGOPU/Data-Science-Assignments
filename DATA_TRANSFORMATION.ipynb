# %% [markdown]
# Data Preprocessing and Feature Engineering in Machine Learning

# %% [markdown]
# Handle missing values as per the best practices (imputation, removal, etc.).
#
#
# a.Apply scaling techniques to numerical features:
# Standard Scaling
#
#  b. Min-Max Scaling
# Discuss the scenarios where each scaling technique is preferred and why.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/adult_with_headers (1).csv')

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'income'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# income            object
# dtype: object

# %%
#checking null values
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
# Separate numerical and categorical columns

numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

categorical_cols = df.select_dtypes(include='object').columns

print("Numerical Columns:")
print(numerical_cols)

print("\nCategorical Columns:")
print(categorical_cols)
# Out:
# Numerical Columns:
# Index(['age', 'fnlwgt', 'education_num', 'capital_gain', 'capital_loss',
#        'hours_per_week'],
#       dtype='object')
#
# Categorical Columns:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'sex', 'native_country', 'income'],
#       dtype='object')

# %%
#standard Scaling
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

df_standard_scaled = df.copy()

df_standard_scaled[numerical_cols] = scaler.fit_transform(
    df_standard_scaled[numerical_cols]
)

df_standard_scaled.head()
# Out:
#         age          workclass    fnlwgt   education  education_num  \
# 0  0.030671          State-gov -1.063611   Bachelors       1.134739
# 1  0.837109   Self-emp-not-inc -1.008707   Bachelors       1.134739
# 2 -0.042642            Private  0.245079     HS-grad      -0.420060
# 3  1.057047            Private  0.425801        11th      -1.197459
# 4 -0.775768            Private  1.408176   Bachelors       1.134739
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# ...

# %%
#min-max scaler
from sklearn.preprocessing import MinMaxScaler

minmax = MinMaxScaler()

df_minmax_scaled = df.copy()

df_minmax_scaled[numerical_cols] = minmax.fit_transform(
    df_minmax_scaled[numerical_cols]
)

df_minmax_scaled.head()
# Out:
#         age          workclass    fnlwgt   education  education_num  \
# 0  0.301370          State-gov  0.044302   Bachelors       0.800000
# 1  0.452055   Self-emp-not-inc  0.048238   Bachelors       0.800000
# 2  0.287671            Private  0.138113     HS-grad       0.533333
# 3  0.493151            Private  0.151068        11th       0.400000
# 4  0.150685            Private  0.221488   Bachelors       0.800000
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# ...

# %% [markdown]
# When Standard Scaling is Preferred
#
# Use when:
#
# Data follows normal distribution
# Algorithms depend on distance/math calculations

# %% [markdown]
# When Min-Max Scaling is Preferred
#
# Use when:
#
# Data does not follow normal distribution
# Neural Networks are used
# Need values between 0 and 1

# %% [markdown]
# Encoding techniques

# %% [markdown]
# One-Hot Encoding
#
# Apply to columns with less than 5 categories.

# %%
for col in categorical_cols:
    print(col, df[col].nunique())
# Out:
# workclass 9
# education 16
# marital_status 7
# occupation 15
# relationship 6
# race 5
# sex 2
# native_country 42
# income 2

# %%
small_cat_cols = [col for col in categorical_cols if df[col].nunique() < 5]

df_onehot = pd.get_dummies(df, columns=small_cat_cols)

df_onehot.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race  \
# 0        Never-married        Adm-clerical   Not-in-family   White
# 1   Married-civ-spouse     Exec-managerial         Husband   White
# 2             Divorced   Handlers-cleaners   Not-in-family   White
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4   Married-civ-spouse      Prof-specialty            Wife   Black
#
#    capital_gain  capital_loss  hours_per_week  native_country  sex_ Female  \
# 0          2174             0              40   United-States        False
# ...

# %% [markdown]
# Pros of One-Hot Encoding
#
#
# Advantages
#
# No ordinal relationship created
# Improves performance for many ML models
#
#
# Disadvantages
#
# Creates many columns
# Increases dimensionality

# %% [markdown]
# Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
large_cat_cols = [col for col in categorical_cols if df[col].nunique() >= 5]


label_encoder = LabelEncoder()

for col in large_cat_cols:
    df[col] = label_encoder.fit_transform(df[col])

df.head()
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   39          7   77516          9             13               4
# 1   50          6   83311          9             13               2
# 2   38          4  215646         11              9               0
# 3   53          4  234721          1              7               2
# 4   28          4  338409          9             13               2
#
#    occupation  relationship  race      sex  capital_gain  capital_loss  \
# 0           1             1     4     Male          2174             0
# 1           4             0     4     Male             0             0
# 2           6             1     4     Male             0             0
# 3           6             0     2     Male             0             0
# 4          10             5     2   Female             0             0
#
#    hours_per_week  native_country  income
# 0              40              39   <=50K
# 1              13              39   <=50K
# ...

# %% [markdown]
# Pros of Label Encoding:
#
#
# Advantages
#
#
# Simple and memory efficient
# Useful for tree-based models
#
#
# Disadvantages
#
# Creates artificial order
# May mislead linear models

# %% [markdown]
# Feature Engineering

# %%
df['net_capital'] = df['capital_gain'] - df['capital_loss']

df[['capital_gain','capital_loss','net_capital']].head()
# Out:
#    capital_gain  capital_loss  net_capital
# 0          2174             0         2174
# 1             0             0            0
# 2             0             0            0
# 3             0             0            0
# 4             0             0            0

# %%
df['age_group'] = pd.cut(
    df['age'],
    bins=[0,25,45,65,100],
    labels=['Young','Adult','Middle_Age','Senior']
)

df[['age','age_group']].head()
# Out:
#    age   age_group
# 0   39       Adult
# 1   50  Middle_Age
# 2   38       Adult
# 3   53  Middle_Age
# 4   28       Adult

# %%
#skewness
df[numerical_cols].skew()
#skweness detected  in capital gain and capital loss
# Out:
# age                0.558743
# fnlwgt             1.446980
# education_num     -0.311676
# capital_gain      11.953848
# capital_loss       4.594629
# hours_per_week     0.227643
# dtype: float64

# %% [markdown]
# apply log transformation

# %%
sns.histplot(df['capital_gain'], kde=True)
plt.show()

# %%
df['capital_gain_log'] = np.log1p(df['capital_gain'])

# %%
sns.histplot(df['capital_gain_log'], kde=True)
plt.show()

# %%
# benefits of logtransformation
#reduces skewness
#makes distribution normal
